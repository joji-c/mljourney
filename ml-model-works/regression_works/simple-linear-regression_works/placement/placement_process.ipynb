# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\jojic\\OneDrive\\Desktop\\mljourney\\ml-model-works\\regression_works\\simple-linear-regression_works\\placement\\placement.csv.xls")

# %%
df.columns
# Out:
# Index(['cgpa', 'placement_exam_marks', 'placed'], dtype='object')

# %%
col=['cgpa', 'placement_exam_marks','placed']
sns.heatmap(df[col].corr(),annot=True)
# Out:
# <Axes: >
