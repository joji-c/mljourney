# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\jojic\\OneDrive\\Desktop\\mljourney\\ml-model-works\\regression_works\\simple-linear-regression_works\\tv-marketing-casestudy\\tvmarketing.csv.xls")

# %%
df.columns
# Out:
# Index(['TV', 'Sales'], dtype='object')

# %%
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
sns.regplot(x=df["TV"],y=df["Sales"])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [0.04810781]
# 6.865601946946056

# %%
#if x=230.1
var1=0.04652973*230.1+7.119638430592953
var1
#here given y=22 and predicted y=17 ,error=4
# Out:
# 17.826129303592953

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([17.19434775, 13.36977723, 17.46375146, 20.18665324,  9.00639928,
#        18.49325849, 13.3264802 , 15.05355041, 11.11352116, 16.05900355,
#        19.43617148, 18.03142356, 10.49774125, 12.78767278, 19.07536294,
#        20.62443427, 19.64303504, 14.77933592,  8.93423758, 17.13661838,
#        18.40185366, 20.345409  , 18.5654202 , 11.46951892, 18.40666445,
#        17.90634327, 15.31814334,  9.63180075, 16.68440501,  8.76586026,
#        10.54103827, 10.19466208, 16.81429609, 15.28927866, 15.106469  ,
#         7.79889337, 17.56477785, 10.15617583, 17.37715741, 12.14783897])
