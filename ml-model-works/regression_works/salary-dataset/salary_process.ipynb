# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\jojic\\OneDrive\\Desktop\\mljourney\\ml-model-works\\regression_works\\salary-dataset\\Salary_dataset.csv.xls")

# %%
sns.regplot(x=df["YearsExperience"],y=df["Salary"])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
x=df.iloc[:,1:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [9469.6069012]
# 25203.5855802449

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
print("r2_score :",r2_score(y_test,y_pred)*100) 
print("MSE :",mean_squared_error(y_test,y_pred))
print("MAE :",mean_absolute_error(y_test,y_pred))
print("RMSE :",root_mean_squared_error(y_test,y_pred))
# Out:
# r2_score : 95.04404484884267
# MSE : 24942746.41030611
# MAE : 4336.74520465804
# RMSE : 4994.271359298182
