# %%
import seaborn as sns
import pandas as pd
import numpy as np
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset("penguins")

# %%
data.shape
# Out:
# (344, 7)

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
data["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.scatterplot(data=data,x="flipper_length_mm",y="body_mass_g")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=data,x="flipper_length_mm",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=data,x="flipper_length_mm",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=data,x="bill_length_mm",y="body_mass_g",hue="island")
sns.despine()#left=true or bottom =true

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=data,x="bill_length_mm",y="body_mass_g",hue="island")
sns.despine()#left=true or bottom =true

# %%
sns.set_style("whitegrid")
sns.set_context("poster")#['paper','notebook','talk','poster']
sns.scatterplot(data=data,x="bill_length_mm",y="body_mass_g",hue="island")
sns.despine()#left=true or bottom =true

# %%
sns.set_style("whitegrid")
sns.set_context("notebook")#['paper','notebook','talk','poster']
sns.scatterplot(data=data,x="bill_length_mm",y="body_mass_g",hue="island",palette="deep") #[bright,pastel,dark,muted,deep,colorblind]
sns.despine()#left=true or bottom =true

# %%
sns.stripplot(data=data,x="island",y="body_mass_g")
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.stripplot(data=data,x="species",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.histplot(data=data,x="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.regplot(data=data,x="flipper_length_mm",y="body_mass_g",color="grey")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.lineplot(data=data,x="flipper_length_mm",y="body_mass_g")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.lineplot(data=data,x="flipper_length_mm",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.lineplot(data=data,x="flipper_length_mm",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.barplot(data=data,x="flipper_length_mm",y="body_mass_g")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.barplot(data=data,x="island",y="body_mass_g",hue="sex")
sns.set_style("whitegrid")

# %%
data.groupby("island")["body_mass_g"].mean()
# Out:
# island
# Biscoe       4716.017964
# Dream        3712.903226
# Torgersen    3706.372549
# Name: body_mass_g, dtype: float64

# %%
sns.barplot(data=data,x="island",y="body_mass_g",hue="sex",estimator=np.sum)
sns.set_style("whitegrid")

# %%
sns.boxplot(data=data,x="species",y="body_mass_g")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(data=data,x="species",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=data,x="species",y="body_mass_g")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=data,x="species",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=data,x="species",y="body_mass_g",hue="sex",split=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.kdeplot(data=data,x="body_mass_g",hue="sex",fill=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
data.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
columns=['bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']
data[columns].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(data[columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
tps=sns.load_dataset("tips")

# %%
tps.isnull().sum()
tps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
col=["total_bill","tip","size"]
sns.heatmap(tps[col].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(data=tps,x="day",y="tip",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(data=tps,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=tps,x="smoker",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.stripplot(data=tps,x="day",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(data=tps,x="total_bill",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.regplot(data=tps,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(data=tps,x="size",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.kdeplot(data=tps,x="size",fill=True)
# Out:
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.violinplot(data=tps,x="day",y="size",hue="sex",split=True)
# Out:
# <Axes: xlabel='day', ylabel='size'>

# %%
tps.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.lineplot(data=tps,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=tps,x="day",y="total_bill",estimator=np.sum)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tps,x="day",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
