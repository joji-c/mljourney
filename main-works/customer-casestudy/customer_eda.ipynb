# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\jojic\\OneDrive\\Desktop\\mljourney\\main-works\\customer-casestudy\\cleaned_customer_data.csv")
df.columns
# Out:
# Index(['id', 'CustomerID', 'Country', 'Age', 'Gender', 'Salary', 'Purchased',
#        'SpendingScore', 'VisitsPerMonth', 'SatisfactionScore', 'JoinDate',
#        'Churn'],
#       dtype='object')

# %%
sns.boxplot(data=df,x="Gender",y="Salary")
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
sns.histplot(data=df,x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df,x="Salary")
df.columns
# Out:
# Index(['id', 'CustomerID', 'Country', 'Age', 'Gender', 'Salary', 'Purchased',
#        'SpendingScore', 'VisitsPerMonth', 'SatisfactionScore', 'JoinDate',
#        'Churn'],
#       dtype='object')

# %%
sns.barplot(data=df,x="Country",y="CustomerID")
# Out:
# <Axes: xlabel='Country', ylabel='CustomerID'>

# %%
sns.barplot(data=df,x="Purchased",y="CustomerID")
# Out:
# <Axes: xlabel='Purchased', ylabel='CustomerID'>

# %%
sns.barplot(data=df,x="Churn",y="CustomerID")
# Out:
# <Axes: xlabel='Churn', ylabel='CustomerID'>

# %%
sns.lineplot(data=df,x="Purchased",y="Salary")
# Out:
# <Axes: xlabel='Purchased', ylabel='Salary'>

# %%
sns.scatterplot(data=df,x="Age",y="SpendingScore",hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='SpendingScore'>

# %%
sns.barplot(data=df,x="Country",y="Churn")
# Out:
# <Axes: xlabel='Country', ylabel='Churn'>

# %%
sns.barplot(data=df,y="Purchased",x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='Purchased'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1000 non-null   int64
#  1   CustomerID         1000 non-null   int64
#  2   Country            1000 non-null   object
#  3   Age                1000 non-null   float64
#  4   Gender             1000 non-null   object
#  5   Salary             1000 non-null   float64
#  6   Purchased          1000 non-null   object
#  7   SpendingScore      1000 non-null   int64
#  8   VisitsPerMonth     1000 non-null   int64
#  9   SatisfactionScore  1000 non-null   float64
#  10  JoinDate           1000 non-null   object
#  11  Churn              1000 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 93.9+ KB

# %%
col=["CustomerID","Age","Salary","SpendingScore","VisitsPerMonth","SatisfactionScore","Churn"]
sns.heatmap(df[col].corr(),annot=True)
# Out:
# <Axes: >

# %%
figure,axes=plt.subplots(1,2)
axes[0].plot(df["Age"],df["Churn"])
axes[1].plot(df["Salary"],df["Churn"])
