# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\jojic\\OneDrive\\Desktop\\mljourney\\pandas-works\\world-famous\\world_famous_places_2024.csv")
print(df.head())
print(df.columns)
df.isnull().sum()
# Out:
#             Place_Name        Country              City  \
# 0         Eiffel Tower         France             Paris
# 1         Times Square  United States     New York City
# 2        Louvre Museum         France             Paris
# 3  Great Wall of China          China  Beijing/Multiple
# 4            Taj Mahal          India              Agra
#
#    Annual_Visitors_Millions                Type UNESCO_World_Heritage  \
# 0                       7.0      Monument/Tower                    No
# 1                      50.0      Urban Landmark                    No
# 2                       8.7              Museum                   Yes
# 3                      10.0   Historic Monument                   Yes
# 4                       7.5  Monument/Mausoleum                   Yes
#
#          Year_Built  Entry_Fee_USD   Best_Visit_Month          Region  \
# 0              1889             35  May-June/Sept-Oct  Western Europe
# ...

# %%
df["Type"].unique()
# Out:
# array(['Monument/Tower', 'Urban Landmark', 'Museum', 'Historic Monument',
#        'Monument/Mausoleum', 'Monument/Statue', 'Cultural Building',
#        'Archaeological Site', 'Historic Palace', 'Temple Complex',
#        'Cathedral', 'Park', 'Entertainment District', 'Skyscraper',
#        'Bridge', 'Monument/Memorial', 'Theme Park', 'Natural Wonder',
#        'Historic Tower', 'Clock Tower', 'Palace'], dtype=object)

# %%
df[df["UNESCO_World_Heritage"]=="Yes"]
# Out:
#                Place_Name         Country              City  \
# 2           Louvre Museum          France             Paris
# 3     Great Wall of China           China  Beijing/Multiple
# 4               Taj Mahal           India              Agra
# 5               Colosseum           Italy              Rome
# 6       Statue of Liberty   United States     New York City
# 7      Sydney Opera House       Australia            Sydney
# 8            Machu Picchu            Peru      Cusco Region
# 9          Forbidden City           China           Beijing
# 10             Angkor Wat        Cambodia         Siem Reap
# 11   Notre-Dame Cathedral          France             Paris
# 17        Sagrada Familia           Spain         Barcelona
# 20           Grand Canyon   United States           Arizona
# 21  Great Pyramid of Giza           Egypt             Cairo
# 22  Leaning Tower of Pisa           Italy              Pisa
# 23   Palace of Versailles          France        Versailles
# ...

# %%
df.groupby("Country")["Tourism_Revenue_Million_USD"].sum().idxmax()
# Out:
# 'United States'

# %%
df.groupby("City")["Annual_Visitors_Millions"].mean()
# Out:
# City
# Agra                 7.500000
# Anaheim             16.000000
# Arizona              6.000000
# Athens               4.000000
# Barcelona            4.700000
# Beijing              9.000000
# Beijing/Multiple    10.000000
# Cairo                2.800000
# Cusco Region         1.500000
# Dubai                6.000000
# Las Vegas           41.700000
# London               9.100000
# New York City       25.225000
# Orlando             17.000000
# Paris                9.566667
# Pisa                 5.000000
# Rio de Janeiro       2.200000
# Rome                 7.650000
# San Francisco       15.000000
# Siem Reap            2.600000
# Sydney               8.200000
# Versailles           7.700000
# Washington D.C.      8.500000
# Name: Annual_Visitors_Millions, dtype: float64

# %%
df[df["Year_Built"]==df["Year_Built"].min()]
# Out:
#     Place_Name   Country       City  Annual_Visitors_Millions            Type  \
# 10  Angkor Wat  Cambodia  Siem Reap                       2.6  Temple Complex
#
#    UNESCO_World_Heritage Year_Built  Entry_Fee_USD Best_Visit_Month  \
# 10                   Yes       1150             37          Nov-Feb
#
#             Region  Tourism_Revenue_Million_USD  Average_Visit_Duration_Hours  \
# 10  Southeast Asia                           90                           6.0
#
#                                            Famous_For
# 10  Largest religious monument, Hindu-Buddhist temple
