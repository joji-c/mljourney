# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\jojic\\OneDrive\\Desktop\\mljourney\\cleaning-works\\delhi-casestudy\\delhi_cleaned.csv")
df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'hour', 'day_of_week', 'is_weekend',
#        'season', 'city', 'station', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'co', 'o3', 'temperature', 'humidity', 'wind_speed',
#        'visibility', 'aqi', 'aqi_category'],
#       dtype='object')

# %%
df.head()
# Out:
#    id  year  month  day  hour  day_of_week  is_weekend  season   city  \
# 0   0  2020      1    1     6            4           0  winter  Delhi
# 1   1  2020      1    1    12            4           0  winter  Delhi
# 2   2  2020      1    1    18            4           0  winter  Delhi
# 3   3  2020      1    1    23            4           0  winter  Delhi
# 4   4  2020      1    1     6            4           0  winter  Delhi
#
#                station  ...    no2   so2    co    o3  temperature  humidity  \
# 0   Anand Vihar, Delhi  ...  119.6  47.7  5.19  12.3          9.4       100
# 1   Anand Vihar, Delhi  ...  117.9  39.3  4.32  15.8         20.6        50
# 2   Anand Vihar, Delhi  ...  150.1  36.3  7.13  14.3         12.4        56
# 3   Anand Vihar, Delhi  ...  142.0  30.3  4.90  13.2         14.4        48
# 4  Jahangirpuri, Delhi  ...  138.4  41.5  7.56  15.4          6.8       100
#
#    wind_speed  visibility  aqi  aqi_category
# ...

# %%
sns.barplot(data=df,x="season",y="temperature")
# Out:
# <Axes: xlabel='season', ylabel='temperature'>

# %%
sns.lineplot(data=df,x="year",y="aqi")
# Out:
# <Axes: xlabel='year', ylabel='aqi'>

# %%
sns.scatterplot(data=df,x="humidity",y="visibility")
# Out:
# <Axes: xlabel='humidity', ylabel='visibility'>

# %%
sns.histplot(data=df,x="aqi")
# Out:
# <Axes: xlabel='aqi', ylabel='Count'>

# %%
col=["year","month","latitude","longitude","pm25","pm10","no2","so2","co","o3","temperature","humidity","wind_speed","visibility","aqi"]
sns.heatmap(df[col].corr(),annot=True)
# Out:
# <Axes: >
