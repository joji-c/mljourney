# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\jojic\\OneDrive\\Desktop\\mljourney\\feature-engineering\\ensamble\\dog-health\\dog_health_dataset_10000.csv.xls")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dog Breed    10000 non-null  object
#  1   Dog Age      10000 non-null  int64
#  2   Dog Weight   10000 non-null  float64
#  3   Symptom 1    10000 non-null  object
#  4   Symptom 2    10000 non-null  object
#  5   Symptom 3    10000 non-null  object
#  6   Symptom 4    10000 non-null  object
#  7   Symptom 5    10000 non-null  object
#  8   Disease      10000 non-null  object
#  9   Precautions  10000 non-null  object
#  10  Treatment    10000 non-null  object
#  11  Emergency    10000 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 937.6+ KB

# %%
df.isnull().sum()
# Out:
# Dog Breed      0
# Dog Age        0
# Dog Weight     0
# Symptom 1      0
# Symptom 2      0
# Symptom 3      0
# Symptom 4      0
# Symptom 5      0
# Disease        0
# Precautions    0
# Treatment      0
# Emergency      0
# dtype: int64

# %%
df[df.duplicated()].shape
# Out:
# (0, 12)

# %%
x=df.iloc[:,:8]
y=df.iloc[:,8]
x
# Out:
#                Dog Breed  Dog Age  Dog Weight         Symptom 1  Symptom 2  \
# 0     Labrador Retriever        9        44.2         Hair loss   Diarrhea
# 1        German Shepherd        7        20.6         Skin rash  Hair loss
# 2                 Poodle       15         5.4  Loss of appetite   Vomiting
# 3     Labrador Retriever       12        44.3         Skin rash   Sneezing
# 4             Rottweiler        2        21.2         Skin rash  Hair loss
# ...                  ...      ...         ...               ...        ...
# 9995                 Pug       12        42.7         Skin rash    Limping
# 9996             Bulldog       10        37.2          Sneezing    Limping
# 9997  Labrador Retriever        2        22.3  Loss of appetite   Coughing
# 9998               Boxer        6        10.5          Coughing   Sneezing
# 9999           Dachshund        5        21.7           Limping   Diarrhea
#
#              Symptom 3  Symptom 4         Symptom 5
# ...

# %%
df.columns
# Out:
# Index(['Dog Breed', 'Dog Age', 'Dog Weight', 'Symptom 1', 'Symptom 2',
#        'Symptom 3', 'Symptom 4', 'Symptom 5', 'Disease', 'Precautions',
#        'Treatment', 'Emergency'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct=ColumnTransformer([("encoder",OneHotEncoder(),["Dog Breed","Symptom 1","Symptom 2","Symptom 3","Symptom 4","Symptom 5"])],remainder="passthrough")
x=pd.DataFrame(ct.fit_transform(x))
x
# Out:
#                                                       0
# 0     <Compressed Sparse Row sparse matrix of dtype ...
# 1     <Compressed Sparse Row sparse matrix of dtype ...
# 2     <Compressed Sparse Row sparse matrix of dtype ...
# 3     <Compressed Sparse Row sparse matrix of dtype ...
# 4     <Compressed Sparse Row sparse matrix of dtype ...
# ...                                                 ...
# 9995  <Compressed Sparse Row sparse matrix of dtype ...
# 9996  <Compressed Sparse Row sparse matrix of dtype ...
# 9997  <Compressed Sparse Row sparse matrix of dtype ...
# 9998  <Compressed Sparse Row sparse matrix of dtype ...
# 9999  <Compressed Sparse Row sparse matrix of dtype ...
#
# [10000 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
y=lb.fit_transform(y)
y
# Out:
# array([3, 0, 2, ..., 2, 6, 5], shape=(10000,))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'csr_matrix'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4664\3441512793.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler=StandardScaler()
# ----> 3 x_train=scaler.fit_transform(x_train)
#       4 x_test=scaler.transform(x_test)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
# ...

# %%
df["Disease"].value_counts()
# Out:
# Disease
# Gastroenteritis       1052
# Digestive Disorder    1035
# Cold                  1023
# Viral Infection       1008
# Tick Fever             998
# Kennel Cough           987
# Parvovirus             983
# Fungal Infection       980
# Joint Pain             975
# Allergy                959
# Name: count, dtype: int64
